# %% [markdown]
# # This code registers GAP HUCs into the Spatial Features Registry.  The code is the first run at this and will likely change as a more complete understanding of SFR needs and requirements are established.  There are many notes within the notebook that suggest improvements to the code and the SB structure that we can implement to help support a more fluid SFR process.
#
# # The code highlights how to post large sql queries to gc2.  It also

# %%
import urllib.request as ur
import geopandas as gpd
import subprocess
import requests
from bis2 import gc2
import datetime
import json

#Delete
hucDownload = 'https://usgs-gap-data.s3.amazonaws.com/Nat_Ranges_Ancillary/HUCs_lower48.gdb.zip'

# %%
#Note: This code pulls data down to local disk from direct call to file on amazon s3, 
#it would be ideal to use ScienceBase to access the file of interest and also to do processing in memory (WebLink needs a meaninful title to make that consistently work), 
#also should look into using s3 libraries for python (http://boto3.readthedocs.io/en/latest/reference/services/s3.html)
#Somewhere in this step we should let the data type and SB item "drive" the process.  For example determine appropriate 
#process to get file into geodataframe based on file type.

#Direct HUC Download URL
hucDownload ='https://usgs-gap-data.s3.amazonaws.com/Nat_Ranges_Ancillary/HUCs_lower48.gdb.zip'
#Download GAP HUC12 file to local directory
ur.urlretrieve(hucDownLoad, 'HUCs_lower48.gdb.zip')
#In working directory unzips file
subprocess.call(r'"C:\Program Files\7-Zip\7z.exe" x ' + 'HUCs_lower48.gdb.zip' )
# Out:
# ('HUCs_lower48.gdb.zip', <http.client.HTTPMessage at 0x1f70065b550>)

# %%
#Create GeoDataFrame of GAP HUC12s, from unzipped file
ghuc_gdf = gpd.read_file('HUCs_lower48.gdb', layer='Hucs')

# %%
ghuc_gdf.head(5)
# Out:
#        HUC12RNG STATES    Shape_Area   Shape_Length  \
# 0  030902030300     FL  5.016106e+09  467346.993995
# 1  121102080900     TX  1.114051e+09  287217.454218
# 2  121102080100     TX  5.572368e+08  213775.315108
# 3  121102080600     TX  4.453596e+08  131953.362328
# 4  121102080700     TX  3.380938e+08  112037.983271
#
#                                             geometry
# 0  (POLYGON ((1505886.25 332166.5, 1508386.25 330...
# 1  (POLYGON ((-129847.9686999992 339565.593799999...
# 2  (POLYGON ((-238270.4844000004 355676.25, -2382...
# 3  (POLYGON ((-179788.9061999992 355720.093799999...
# 4  (POLYGON ((-149064.7186999992 366221.343799999...

# %%
#View current coordinate system of file.  This is just a note and can get rid of this step.
#Currently this spatial file does not have an official crs... something to improve in future iterations
ghuc_gdf.crs
# Out:
# {'datum': 'NAD83',
#  'lat_0': 23,
#  'lat_1': 29.5,
#  'lat_2': 45.5,
#  'lon_0': -96,
#  'no_defs': True,
#  'proj': 'aea',
#  'units': 'm',
#  'x_0': 0,
#  'y_0': 0}

# %%
#Transform coordinate system to web mercator
ghuc_gdf = ghuc_gdf.to_crs({'init': 'epsg:3857'}) 
#Print new coordinate system to make sure transformation worked
ghuc_gdf.crs
# Out:
# {'init': 'epsg:3857'}

# %%
#Verify Coordinate System is in web mercator (crs: 3857), if not transform, This needs to be improved upon, right now throws an error
if ghuc_gdf.crs['init'] == 'epsg:3857':
    print ('Coordinate System = Web Mercator, crs: 3857')
else:
    oldCrs = ghuc_gdf.crs['init']
    ghuc_gdf.to_crs({'init': 'epsg:3857'})
    newCrs = ghuc_gdf.crs['init']
    print ('Transformed Coordinate System to ' + newCrs + ' from ' + oldCrs)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-93-d1ea1ca99475> in <module>()
#       1 #Verify Coordinate System is in web mercator (crs: 3857), if not transform
# ----> 2 if ghuc_gdf.crs['init'] == 'epsg:3857':
#       3     print ('Coordinate System = Web Mercator, crs: 3857')
#       4 else:
#       5     oldCrs = ghuc_gdf.crs['init']
#
# KeyError: 'init'

# %%
# Set up the actions/targets for this particular instance
thisRun = {}
thisRun["instance"] = "DataDistillery"
thisRun["db"] = "BCB"
thisRun["baseURL"] = gc2.sqlAPI(thisRun["instance"],thisRun["db"])
thisRun["schema"] = "sfr"
thisRun["commitToDB"] = False

gc2Key = gc2.gc2Keys["datadistillery_bcb"]
SbUrl = 'https://www.sciencebase.gov/catalog/item/56d496eee4b015c306f17a42'

# %%
#This step helps troubleshoot the upload of many large complex features, which can not be uploaded in one run due to timing out of server
#Return GAP HUC records already in SFR into a list called lookup.  Lookup will be used to ensure we don't duplicate records

q_recordToSearch = "SELECT registration->'sourceLookup' as lookup FROM sfr.sfr_poly where ftype= 'https://www.sciencebase.gov/vocab/term/5898adfde4b050e6125b807f' " 
recordToSearch = requests.get(thisRun["baseURL"]+"&q="+q_recordToSearch).json()
p = recordToSearch['features']
lookup = []
for f in p:
    string = f['properties']['lookup']
    if string.startswith('"') and string.endswith('"'):
        string = string[1:-1]  #For some reason these values are coming back with double quotes, this removes outer quote
        lookup.append(string)
lenList = len(lookup)
cntExisting = 0 
existingList = []
    
for row in ghuc_gdf.itertuples():
    #This if statement checks to see if the HUC was already processed, if it was we just record that and move on. 
    if row.HUC12RNG in lookup:
        cntExisting += 1
        existingList.append({'existingHuc': r})
    else:
        #Register a spatial feature
        #Uses the ScienceBase item and data brought into a geodataframe with crs 3857 to register an item

        #def registerSFR (SbUrl, gdf):
        poly = str(row.geometry)
        title = ('GAP_HUC_' + row.HUC12RNG)
        spat_cert = 'https://www.sciencebase.gov/vocab/term/5822257ee4b0b3d9add24304'
        ftype = 'https://www.sciencebase.gov/vocab/term/5898adfde4b050e6125b807f'
              
        #Build JSON for Registration Information field in SFR 
        #We should bring in information from the SB item to help build this out, example is dataDevelopmentDate, 
        thisRegistration = {}
        thisRegistration["sourceName"] = "USGS Biogeographic Characterization Branch"  #In Future Pull this from SB
        thisRegistration["sourceInfoUrl"] = SbUrl # In Future Pull this from SB
        thisRegistration["sourceFileUrl"] = hucDownload # In Future Pull this from SB
        thisRegistration["registrationDate"] = datetime.datetime.utcnow().isoformat() 
        thisRegistration["sourceLookup"] = row.HUC12RNG
        jd = json.dumps(thisRegistration)
        
        q = "insert into sfr.sfr_poly(registration, spat_cert, title, ftype, the_geom) VALUES ('" + jd + "' ,'"  + spat_cert + "' ,'" \
+ title + "' ,'" + ftype + "', ST_GeomFromText('" + poly + "', 3857))"
        payload = "q=%s&key=%s"%(q,gc2Key)
        url= gc2.baseURLs["sqlapi_datadistillery_bcb"]
        
        try:
            d=[]
            r = requests.post(url,data=payload)
            status = str(r.status_code)
            if r.status_code == 200:
                d.append({'status': status, 'id': str(row.HUC12RNG)})
            else:
                d.append({'status': status, 'id': str(row.HUC12RNG)})
                print (str(row.HUC12RNG) + ' failed with code: ' + status)
        except requests.exceptions.HTTPError:
                d.append({'status': status, 'id': str(row.HUC12RNG)})
                print (str(row.HUC12RNG) + ' failed with code: ' + status)
# Out:
# 031102021101 failed with code: 502
# 111402070501 failed with code: 502
# 130302010801 failed with code: 503
# 030701060402 failed with code: 503
# 130302010705 failed with code: 503
# 080500030207 failed with code: 503
# 031800020606 failed with code: 503
# 031502030104 failed with code: 503
# 080403020101 failed with code: 503
# 120602010803 failed with code: 503
# 150802000101 failed with code: 503
# 031300060608 failed with code: 503
# 130700070507 failed with code: 503
# 031602010901 failed with code: 503
# 120602010804 failed with code: 503
# 031300070502 failed with code: 503
# 080500020701 failed with code: 503
# 120800060803 failed with code: 503
# 150503010501 failed with code: 503
# 111403040502 failed with code: 503
# 031300031304 failed with code: 503
# 130500040912 failed with code: 503
# 130500041003 failed with code: 503
# 031300031302 failed with code: 503
# 130301020804 failed with code: 503
# 120800070102 failed with code: 503
# 031300031306 failed with code: 503
# 120800020901 failed with code: 503
# 031102020204 failed with code: 503
# 130600111105 failed with code: 503
# 120301050303 failed with code: 503
# 130700070505 failed with code: 503
# 031800020303 failed with code: 503
# 080602020802 failed with code: 503
# 130700070209 failed with code: 503
# 031700020102 failed with code: 503
# 120800040907 failed with code: 503
# 111402090202 failed with code: 503
# 080403030101 failed with code: 503
# 031102020302 failed with code: 503
# 120800020903 failed with code: 503
# 031300060701 failed with code: 503
# 031102020205 failed with code: 503
# 150400030508 failed with code: 503
# 130700070605 failed with code: 503
# 130600111403 failed with code: 503
# 130700070403 failed with code: 503
# 150502020603 failed with code: 503
# 150802000203 failed with code: 503
# 120100020404 failed with code: 503
# 120200010103 failed with code: 503
# 120602011205 failed with code: 503
# 031700040202 failed with code: 503
# 150803010305 failed with code: 503
# 130500040802 failed with code: 503
# 031700020405 failed with code: 503
# 111402060104 failed with code: 503
# 120301090302 failed with code: 503
# 130700070402 failed with code: 503
# 120601020502 failed with code: 503
# 111402030507 failed with code: 503
# 130700070603 failed with code: 503
# 031403010104 failed with code: 503
# 120601020707 failed with code: 503
# 031502030105 failed with code: 503
# 120601020708 failed with code: 503
# 031300031301 failed with code: 503
# 031502030601 failed with code: 503
# 150400060101 failed with code: 503
# 120602020201 failed with code: 503
# 120800070101 failed with code: 503
# 080403020102 failed with code: 503
# 080500011006 failed with code: 503
# 031502030202 failed with code: 503
# 030702010901 failed with code: 503
# 130700070604 failed with code: 503
# 130700010502 failed with code: 503
# 150802000102 failed with code: 503
# 130600111402 failed with code: 503
# 150400030601 failed with code: 503
# 150503010203 failed with code: 503
# 031403010103 failed with code: 503
# 111402040303 failed with code: 503
# 031502030604 failed with code: 503
# 120702010105 failed with code: 503
# 120100020506 failed with code: 503
# 120301070111 failed with code: 503
# 120602010807 failed with code: 503
# 130500040904 failed with code: 503
# 130302021606 failed with code: 503
# 120702010107 failed with code: 503
# 130500040703 failed with code: 503
# 120200010104 failed with code: 503
# 031403010102 failed with code: 503
# 031700040201 failed with code: 503
# 130500040702 failed with code: 503
# 130600110902 failed with code: 503
# 130301021006 failed with code: 503
# 031403020101 failed with code: 503
# 130600111107 failed with code: 503
# 130301020902 failed with code: 503
# 111403040503 failed with code: 503
# 031502030602 failed with code: 503
# 120100020704 failed with code: 503
# 031300070404 failed with code: 503
# 031403010201 failed with code: 503
# 120800050103 failed with code: 503
# 130302010204 failed with code: 503
# 130302021701 failed with code: 503
# 031300031202 failed with code: 503
# 120800021003 failed with code: 503
# 111402060201 failed with code: 503
# 120601050104 failed with code: 503
# 150502020604 failed with code: 503
# 031800020604 failed with code: 503
# 031300090103 failed with code: 503
# 120100020702 failed with code: 503
# 030602040604 failed with code: 503
# 120100020603 failed with code: 503
# 080602020804 failed with code: 503
# 031602010301 failed with code: 503
# 120200010201 failed with code: 503
# 120800070104 failed with code: 503
# 031700040101 failed with code: 503
# 130302010504 failed with code: 503
# 080500011307 failed with code: 503
# 120601020306 failed with code: 503
# 150400030602 failed with code: 503
# 031700010204 failed with code: 503
# 031800020603 failed with code: 503
# 031300070503 failed with code: 503
# 130302021802 failed with code: 503
# 120800040905 failed with code: 503
# 031300060610 failed with code: 503
# 030701040803 failed with code: 503
# 130500040902 failed with code: 503
# 031602010502 failed with code: 503
# 031800020305 failed with code: 503
# 130500040901 failed with code: 503
# 120200010102 failed with code: 503
# 031700010704 failed with code: 503
# 120301050402 failed with code: 503
# 080500030303 failed with code: 503
# 150400060107 failed with code: 503
# 031502030701 failed with code: 503
# 031102020106 failed with code: 503
# 030702020404 failed with code: 503
# 130600110901 failed with code: 503
# 111403040402 failed with code: 503
# 120601020705 failed with code: 503
# 130302021609 failed with code: 503
# 120301020602 failed with code: 503
# 080500030304 failed with code: 503
# 120602011208 failed with code: 503
# 031502010802 failed with code: 503
# 030702020202 failed with code: 503
# 031300031503 failed with code: 503
# 120800040902 failed with code: 503
# 150400060106 failed with code: 503
# 031800020703 failed with code: 503
# 031602010507 failed with code: 503
# 120200010101 failed with code: 503
# 031700010202 failed with code: 503
# 120301050302 failed with code: 503
# 111402020102 failed with code: 503
# 031800020701 failed with code: 503
# 130302010605 failed with code: 503
# 120800020807 failed with code: 503
# 031402020104 failed with code: 503
# 031700040102 failed with code: 503
# 150400060102 failed with code: 503
# 120301050405 failed with code: 503
# 120601050402 failed with code: 503
# 080402070101 failed with code: 503
# 150503010207 failed with code: 503
# 150803010202 failed with code: 503
# 130600111108 failed with code: 503
# 031502030702 failed with code: 503
# 031502030106 failed with code: 503
# 120601020302 failed with code: 503
# 080500030203 failed with code: 503
# 031300070804 failed with code: 503
# 150503010202 failed with code: 503
# 120301020601 failed with code: 503
# 031700020403 failed with code: 503
# 030702010803 failed with code: 503
# 031300060609 failed with code: 503
# 130600111401 failed with code: 503
# 130302021803 failed with code: 503
# 150802000104 failed with code: 503
# 120100020601 failed with code: 503
# 031602010302 failed with code: 503
# 120301070302 failed with code: 503
# 130700070506 failed with code: 503
# 130500032101 failed with code: 503
# 031502010401 failed with code: 503
# 030702020103 failed with code: 503
# 111402090201 failed with code: 503
# 130302010603 failed with code: 503
# 120800041004 failed with code: 503
# 130302010702 failed with code: 503
# 120100020602 failed with code: 503
# 120301090301 failed with code: 503
# 120602011204 failed with code: 503
# 150503010502 failed with code: 503
# 080402070103 failed with code: 503
# 030702010802 failed with code: 502
# 031300070903 failed with code: 503
# 130600111109 failed with code: 503
# 120100020303 failed with code: 503
# 130301021004 failed with code: 503
# 030701060403 failed with code: 503
# 030702020403 failed with code: 503
# 031502010801 failed with code: 503
# 120800040807 failed with code: 503
# 130302010701 failed with code: 503
# 120800050102 failed with code: 503
# 150502020602 failed with code: 503
# 111402030508 failed with code: 503
# 031300090101 failed with code: 503
# 080602020707 failed with code: 503
# 031300060704 failed with code: 503
# 031502010403 failed with code: 503
# 031300031205 failed with code: 503
# 150502020504 failed with code: 503
# 030602040501 failed with code: 503
# 150503010504 failed with code: 503
# 120800020802 failed with code: 503
# 031800020302 failed with code: 503
# 080500030201 failed with code: 503
# 150502020502 failed with code: 503
# 120601020101 failed with code: 503
# 130700070501 failed with code: 503
# 031300070403 failed with code: 503
# 080500010802 failed with code: 503
# 080602020803 failed with code: 503
# 120301050306 failed with code: 503
# 120100020607 failed with code: 503
# 031300031403 failed with code: 503
# 150802000204 failed with code: 503
# 120602010802 failed with code: 503
# 120601020801 failed with code: 503
# 080500030302 failed with code: 503
# 031300031404 failed with code: 503
# 031700020401 failed with code: 503
# 031800020702 failed with code: 503
# 031300090102 failed with code: 503
# 120601020706 failed with code: 503
# 031700010403 failed with code: 503
# 120800040901 failed with code: 503
# 150502020501 failed with code: 503
# 111402080102 failed with code: 503
# 120100020104 failed with code: 503
# 150502020605 failed with code: 503
# 111402090106 failed with code: 503
# 150502020606 failed with code: 503
# 120602011301 failed with code: 503
# 130301020802 failed with code: 503
# 150502020506 failed with code: 503
# 111402030505 failed with code: 503
# 120602010903 failed with code: 503
# 111402030402 failed with code: 503
# 130600110801 failed with code: 503
# 080500011010 failed with code: 503
# 031602010504 failed with code: 503
# 130301020904 failed with code: 503
# 030701040802 failed with code: 503
# 130301021005 failed with code: 503
# 031102020202 failed with code: 503
# 120601020503 failed with code: 503
# 120602010805 failed with code: 503
# 111403040506 failed with code: 503
# 080402060801 failed with code: 503
# 120601050403 failed with code: 503
# 120601020304 failed with code: 503
# 120100020703 failed with code: 503
# 031300031502 failed with code: 503
# 030702020402 failed with code: 503
# 120301070301 failed with code: 503
# 150802000201 failed with code: 503
# 031800020301 failed with code: 503
# 120601050404 failed with code: 503
# 120301020401 failed with code: 503
# 150502020601 failed with code: 503
# 031300031204 failed with code: 503
# 130700070602 failed with code: 503
# 120301050305 failed with code: 503
# 130302010503 failed with code: 503
# 031300070805 failed with code: 503
# 120601020709 failed with code: 503
# 120602011107 failed with code: 503
# 130700070401 failed with code: 503
# 031102020203 failed with code: 503
# 031402020102 failed with code: 503
# 111402040302 failed with code: 503
# 080403030102 failed with code: 503
# 150803010205 failed with code: 503
# 031700010205 failed with code: 503
# 130500040202 failed with code: 503
# 130500032105 failed with code: 503
# 130500032104 failed with code: 503
# 120702010106 failed with code: 503
# 030701040602 failed with code: 503
# 031602010506 failed with code: 503
# 130500040203 failed with code: 503
# 130700070208 failed with code: 503
# 080602021001 failed with code: 503
# 080500011308 failed with code: 503
# 031300060703 failed with code: 503
# 120602011206 failed with code: 503
# 080403030203 failed with code: 503
# 130700070502 failed with code: 503
# 130600110905 failed with code: 503
# 120602010902 failed with code: 503
# 120100020701 failed with code: 503
# 120800020804 failed with code: 503
# 080403030202 failed with code: 503
# 120601020710 failed with code: 503
# 130600110903 failed with code: 503
# 031300031201 failed with code: 503
# 120301070108 failed with code: 503
# 130500040209 failed with code: 503
# 080403030201 failed with code: 503
# 120601020504 failed with code: 503
# 120301050301 failed with code: 503
# 120601050302 failed with code: 503
# 150503010206 failed with code: 503
# 111403040401 failed with code: 503
# 030701060401 failed with code: 503
# 031800020307 failed with code: 503
# 031102020104 failed with code: 503
# 031300060607 failed with code: 503
# 120601020711 failed with code: 503
# 031502010803 failed with code: 503
# 130302010502 failed with code: 503
# 150803010204 failed with code: 503
# 031300030905 failed with code: 503
# 120301070110 failed with code: 503
# 130600111705 failed with code: 503
# 120100020403 failed with code: 503
# 120800020902 failed with code: 503
# 080500011304 failed with code: 503
# 150502020505 failed with code: 503
# 031402020103 failed with code: 503
# 120800060701 failed with code: 503
# 150400060105 failed with code: 503
# 130302021507 failed with code: 503
# 120601020308 failed with code: 503
# 120100020505 failed with code: 503
# 031300070501 failed with code: 503
# 150400060108 failed with code: 503
# 130500040707 failed with code: 503
# 031300031203 failed with code: 503
# 031300070402 failed with code: 503
# 150801010301 failed with code: 503
# 030602040502 failed with code: 503
# 111403040403 failed with code: 503
# 120301070206 failed with code: 503
# 150503040101 failed with code: 503
# 150803010108 failed with code: 503
# 080402070102 failed with code: 503
# 120601020307 failed with code: 503
# 120800020805 failed with code: 503
# 080500011004 failed with code: 503
# 031800020602 failed with code: 503
# 080602020503 failed with code: 503
# 120602010808 failed with code: 503
# 150803010302 failed with code: 503
# 080602020502 failed with code: 503
# 031700020404 failed with code: 503
# 130301021002 failed with code: 503
# 120800050101 failed with code: 503
# 130302021104 failed with code: 503
# 120800020806 failed with code: 503
# 030701040804 failed with code: 503
# 111402040202 failed with code: 503
# 120301020604 failed with code: 503
# 150502020507 failed with code: 503
# 080500011306 failed with code: 503
# 030702020303 failed with code: 503
# 130302021103 failed with code: 503
# 031102020105 failed with code: 503
# 120100020106 failed with code: 503
# 130302021508 failed with code: 502
# 150400030603 failed with code: 503
# 130302010602 failed with code: 503
# 130500032207 failed with code: 503
# 120301020304 failed with code: 503
# 120301050401 failed with code: 503
# 150502020608 failed with code: 503
# 120800041003 failed with code: 503
# 120301020303 failed with code: 503
# 120601020601 failed with code: 503
# 150400060109 failed with code: 503
# 130500032002 failed with code: 503
# 080500011305 failed with code: 503
# 031602010408 failed with code: 503
# 031800020304 failed with code: 503
# 130700070306 failed with code: 503
# 031300060611 failed with code: 503
# 120100020504 failed with code: 503
# 030701040805 failed with code: 503
# 031700010201 failed with code: 503
# 150803010106 failed with code: 503
# 150802000202 failed with code: 503
# 120301020402 failed with code: 503
# 120800041002 failed with code: 503
# 031502030108 failed with code: 503
# 120800040806 failed with code: 503
# 031300031402 failed with code: 503
# 120800021001 failed with code: 503
# 150502020509 failed with code: 503
# 031300070902 failed with code: 503
# 031700010305 failed with code: 503
# 120601050105 failed with code: 503
# 130700070305 failed with code: 503
# 031800010801 failed with code: 503
# 120602010801 failed with code: 503
# 150803010301 failed with code: 503
# 130600110802 failed with code: 503
# 031502010301 failed with code: 503
# 080500030202 failed with code: 503
# 120100010503 failed with code: 503
# 111402080101 failed with code: 503
# 031502010805 failed with code: 503
# 130500040208 failed with code: 503
# 120800020801 failed with code: 503
# 130301021003 failed with code: 503
# 120100020405 failed with code: 503
# 031300060702 failed with code: 503
# 080402070203 failed with code: 503
# 031402020101 failed with code: 503
# 120602011109 failed with code: 503
# 111403040501 failed with code: 503
# 150803010201 failed with code: 503
# 031300030902 failed with code: 503
# 031300070303 failed with code: 503
# 031300060606 failed with code: 503
# 031602020601 failed with code: 503
# 150803010203 failed with code: 503
# 031602010202 failed with code: 503
# 120800020803 failed with code: 503
# 031700020402 failed with code: 503
# 080500011005 failed with code: 503
# 130301020901 failed with code: 503
# 120601050106 failed with code: 503
# 080602020704 failed with code: 503
# 031502010404 failed with code: 503
# 130600110906 failed with code: 503
# 150502020607 failed with code: 503
# 120301050202 failed with code: 503
# 150503040102 failed with code: 503
# 031700010703 failed with code: 503
# 111402030504 failed with code: 503
# 080500030301 failed with code: 503
# 130500032106 failed with code: 503
# 080402060802 failed with code: 503
# 031800020601 failed with code: 503
# 120800040805 failed with code: 503
# 130500040206 failed with code: 503
# 150803010107 failed with code: 503
# 130302010601 failed with code: 503
# 120301020603 failed with code: 503
# 120602010904 failed with code: 503
# 080302080201 failed with code: 503
# 120601020604 failed with code: 503
# 120301020301 failed with code: 503
# 080500020602 failed with code: 503
# 120100020102 failed with code: 503
# 130500040704 failed with code: 503
# 130700070601 failed with code: 503
# 030702010801 failed with code: 503
# 130600111202 failed with code: 503
# 130600110804 failed with code: 503
# 120301070109 failed with code: 503
# 031502010806 failed with code: 503
# 031800020101 failed with code: 503
# 130600111707 failed with code: 503
# 080500030103 failed with code: 503
# 120100020107 failed with code: 503
# 111402030403 failed with code: 503
# 130500040705 failed with code: 503
# 031502030308 failed with code: 503
# 120800060801 failed with code: 503
# 130700070207 failed with code: 503
# 030701060307 failed with code: 503
# 120800021002 failed with code: 503
# 111403040505 failed with code: 503
# 031502030107 failed with code: 503
# 031800020306 failed with code: 503
# 080500011007 failed with code: 503
# 080500011303 failed with code: 503
# 111402030503 failed with code: 503
# 120601050301 failed with code: 503
# 031602010108 failed with code: 503
# 130302021102 failed with code: 503
# 120602011203 failed with code: 503
# 111403040504 failed with code: 503
# 150801010302 failed with code: 503
# 120301020605 failed with code: 503
# 120602011207 failed with code: 503
# 031300070204 failed with code: 503
# 031700010203 failed with code: 503
# 080500011203 failed with code: 503
# 120301070204 failed with code: 503
# 031502010804 failed with code: 503
# 031300031501 failed with code: 503
# 080500011002 failed with code: 503
# 130600111704 failed with code: 503
# 150503010205 failed with code: 503
# 130500040706 failed with code: 503
# 031403010101 failed with code: 503
# 120601050405 failed with code: 503
# 130500032003 failed with code: 503
# 031102020201 failed with code: 503
# 030701040801 failed with code: 503
# 031300030901 failed with code: 503
# 031700010304 failed with code: 503
# 120601020303 failed with code: 503
# 120602010906 failed with code: 503
# 120100020105 failed with code: 503
# 130500040207 failed with code: 503
# 111402090104 failed with code: 503
# 120100010604 failed with code: 503
# 120301050205 failed with code: 503
# 080302080102 failed with code: 503
# 030702020101 failed with code: 503
# 030702020401 failed with code: 503
# 030701060308 failed with code: 503
# 031300070802 failed with code: 503
# 130600111204 failed with code: 503
# 030702020201 failed with code: 503
# 120601020505 failed with code: 503
# 031700010603 failed with code: 503
# 150503040201 failed with code: 503
# 031502010402 failed with code: 503
# 120601020103 failed with code: 503
# 130600110904 failed with code: 503
# 031300030904 failed with code: 503
# 150803010101 failed with code: 503
# 130302010205 failed with code: 503
# 120602010809 failed with code: 503
# 031300070401 failed with code: 503
# 120301070205 failed with code: 503
# 030602040401 failed with code: 503
# 130302021208 failed with code: 503
# 031700010602 failed with code: 503
# 150503010506 failed with code: 503
# 130302021605 failed with code: 503
# 120800060802 failed with code: 503
# 130500040306 failed with code: 503
# 130302021506 failed with code: 503
# 031602020602 failed with code: 503
# 130302010501 failed with code: 503
# 030702020102 failed with code: 503
# 031300031401 failed with code: 503
# 031300060406 failed with code: 503
# 150503040103 failed with code: 503
# 031502010405 failed with code: 503
# 031502010305 failed with code: 503
# 080302080202 failed with code: 503
# 031300070301 failed with code: 503
# 120301060507 failed with code: 503
# 130600111703 failed with code: 503
# 031602010104 failed with code: 503
# 120800060704 failed with code: 503
# 111402030502 failed with code: 503
# 120601020309 failed with code: 503
# 120800040803 failed with code: 503
# 120100020206 failed with code: 503
# 120301050201 failed with code: 503
# 150503010505 failed with code: 503
# 120601050303 failed with code: 503
# 150503010401 failed with code: 503
# 130600110907 failed with code: 503
# 031502030203 failed with code: 503
# 120800040804 failed with code: 503
# 120800020703 failed with code: 503
# 120800041001 failed with code: 503
# 150503010201 failed with code: 503
# 031300070803 failed with code: 503
# 150503010503 failed with code: 503
# 150503010204 failed with code: 503
# 031300030903 failed with code: 503
# 120800020606 failed with code: 503
# 031300031103 failed with code: 503
# 031300031102 failed with code: 503
# 120100020101 failed with code: 503
# 080402060803 failed with code: 503
# 130600110803 failed with code: 503
# 080602020701 failed with code: 503
# 080402070202 failed with code: 503
# 120602010806 failed with code: 503
# 031602010102 failed with code: 503
# 130301020903 failed with code: 503
# 120100030305 failed with code: 503
# 120800020706 failed with code: 503
# 120601050501 failed with code: 503
# 080402060703 failed with code: 503
# 080602020501 failed with code: 503
# 130302021206 failed with code: 503
# 120301020403 failed with code: 503
# 120601050407 failed with code: 503
# 031502030402 failed with code: 503
# 111403070206 failed with code: 503
# 120602011110 failed with code: 503
# 031502010306 failed with code: 503
# 130600111708 failed with code: 503
# 120602010401 failed with code: 503
# 120100020401 failed with code: 503
# 130500040701 failed with code: 503
# 120301020302 failed with code: 503
# 031300070901 failed with code: 503
# 120601050502 failed with code: 503
# 030701040603 failed with code: 503
# 111403060402 failed with code: 503
# 120800060702 failed with code: 503
# 080602020705 failed with code: 503
# 031602010407 failed with code: 503
# 120602010907 failed with code: 503
# 130302021105 failed with code: 503
# 111403060401 failed with code: 503
# 031602010201 failed with code: 503
# 150803010105 failed with code: 503
# 080500010801 failed with code: 503
# 030602040603 failed with code: 503
# 130500040201 failed with code: 503
# 031300030704 failed with code: 503
# 031800010803 failed with code: 503
# 150400030604 failed with code: 503
# 111402090105 failed with code: 503
# 031502011201 failed with code: 503
# 120601020803 failed with code: 503
# 031700010402 failed with code: 503
# 111403060406 failed with code: 503
# 150503040104 failed with code: 503
# 031102020103 failed with code: 503
# 031502010302 failed with code: 503
# 150502020503 failed with code: 503
# 031602010403 failed with code: 503
# 120301020305 failed with code: 503
# 120800020701 failed with code: 503
# 120301070104 failed with code: 503
# 120800040706 failed with code: 503
# 120800060703 failed with code: 503
# 120100010605 failed with code: 503
# 111402040201 failed with code: 503
# 150803010103 failed with code: 503
# 120601020102 failed with code: 503
# 130302021207 failed with code: 503
# 130500040506 failed with code: 503
# 030701060302 failed with code: 503
# 120601020802 failed with code: 503
# 031800020404 failed with code: 503
# 120100010608 failed with code: 503
# 130302010103 failed with code: 503
# 031602010406 failed with code: 503
# 031800020201 failed with code: 503
# 080500011302 failed with code: 503
# 130700070205 failed with code: 503
# 031102020102 failed with code: 503
# 031502010807 failed with code: 503
# 130600110909 failed with code: 503
# 120602011202 failed with code: 503
# 150502020508 failed with code: 503
# 120301070106 failed with code: 503
# 120601020605 failed with code: 503
# 120601050406 failed with code: 503
# 120301020606 failed with code: 503
# 150502020705 failed with code: 503
# 111403070205 failed with code: 503
# 031502010406 failed with code: 503
# 111403070207 failed with code: 503
# 080602020504 failed with code: 503
# 150503010402 failed with code: 503
# 120100020103 failed with code: 503
# 080402060706 failed with code: 503
# 150502020701 failed with code: 503
# 031800010904 failed with code: 503
# 031800020202 failed with code: 503
# 120601050107 failed with code: 503
# 120800040801 failed with code: 503
# 120800030908 failed with code: 503
# 031300060605 failed with code: 503
# 080402060805 failed with code: 503
# 150400030605 failed with code: 503
# 031300060601 failed with code: 503
# 120100020402 failed with code: 503
# 080402060804 failed with code: 503
# 130500032201 failed with code: 503
# 030701060203 failed with code: 503
# 130301021001 failed with code: 503
# 111403070204 failed with code: 503
# 031300060405 failed with code: 503
# 150502010501 failed with code: 503
# 080602020706 failed with code: 503
# 031602010106 failed with code: 503
# 130700070304 failed with code: 503
# 031502030201 failed with code: 503
# 130600110702 failed with code: 503
# 111403070201 failed with code: 503
# 150400060201 failed with code: 503
# 031300031003 failed with code: 503
# 130600110704 failed with code: 503
# 120100010607 failed with code: 503
# 031300060408 failed with code: 503
# 031602010405 failed with code: 503
# 130500040606 failed with code: 503
# 031800020102 failed with code: 503
# 120800060604 failed with code: 503
# 080602020301 failed with code: 503
# 030701040806 failed with code: 503
# 130700070206 failed with code: 503
# 111403070208 failed with code: 503
# 130600111706 failed with code: 503
# 150803010102 failed with code: 503
# 120800020406 failed with code: 503
# 120601020712 failed with code: 503
# 120601020602 failed with code: 503
# 031300060407 failed with code: 503
# 080402060704 failed with code: 503
# 120301070203 failed with code: 503
# 150503010507 failed with code: 502
# 150502020702 failed with code: 503
# 120601020310 failed with code: 503
# 120301050107 failed with code: 503
# 120301070107 failed with code: 503
# 031300060602 failed with code: 503
# 080500011301 failed with code: 503
# 111403070203 failed with code: 503
# 120601020805 failed with code: 503
# 031300070801 failed with code: 503
# 111403040303 failed with code: 503
# 111402040301 failed with code: 503
# 130500032206 failed with code: 503
# 130500032001 failed with code: 503
# 150801010303 failed with code: 503
# 130500040304 failed with code: 503
# 130301020803 failed with code: 503
# 080500011003 failed with code: 503
# 130500031901 failed with code: 503
# 030701040702 failed with code: 503
# 030701040703 failed with code: 503
# 111403060408 failed with code: 503
# 120800060508 failed with code: 503
# 031700010601 failed with code: 503
# 031700010303 failed with code: 503
# 080500020504 failed with code: 503
# 120601050408 failed with code: 503
# 031602010107 failed with code: 503
# 130500032203 failed with code: 503
# 120602010905 failed with code: 503
# 120800020704 failed with code: 503
# 150503020102 failed with code: 503
# 120800040802 failed with code: 503
# 150803010104 failed with code: 503
# 111402090103 failed with code: 503
# 031300030701 failed with code: 503
# 130500040205 failed with code: 503
# 130301020701 failed with code: 503
# 150503020101 failed with code: 503
# 031102020101 failed with code: 503
# 130302021404 failed with code: 503
# 120301020208 failed with code: 503
# 031502010303 failed with code: 503
# 111402030401 failed with code: 503
# 130302021101 failed with code: 503
# 031502010702 failed with code: 503
# 031502030307 failed with code: 503
# 031700010302 failed with code: 503
# 130302021604 failed with code: 503
# 120301060506 failed with code: 503
# 030701060204 failed with code: 503
# 031300070201 failed with code: 503
# 080500030105 failed with code: 503
# 030701060301 failed with code: 503
# 031501100802 failed with code: 503
# 031502010502 failed with code: 503
# 031300060603 failed with code: 503
# 031300070302 failed with code: 503
# 031502011203 failed with code: 503
# 080402060707 failed with code: 503
# 130301020604 failed with code: 503
# 031602020603 failed with code: 503
# 130600111702 failed with code: 503
# 031300060404 failed with code: 503
# 130700070303 failed with code: 503
# 111402030308 failed with code: 503
# 120100010502 failed with code: 503
# 120602011004 failed with code: 503
# 120602010901 failed with code: 503
# 031300030804 failed with code: 503
# 031800020203 failed with code: 503
# 111402030501 failed with code: 503
# 150503040105 failed with code: 503
# 031602010101 failed with code: 503
# 111403040302 failed with code: 503
# 130600110908 failed with code: 503
# 120301020404 failed with code: 503
# 150400060202 failed with code: 503
# 150400060203 failed with code: 503
# 031502010407 failed with code: 503
# 031602010103 failed with code: 503
# 031700010702 failed with code: 503
# 120800030904 failed with code: 503
# 031800010905 failed with code: 503
# 120301020607 failed with code: 503
# 120602011106 failed with code: 503
# 080500011104 failed with code: 503
# 150502010504 failed with code: 503
# 031502030306 failed with code: 503
# 031501100901 failed with code: 503
# 030701060404 failed with code: 503
# 031300060604 failed with code: 503
# 130302021505 failed with code: 503
# 031800010901 failed with code: 503
# 120601020104 failed with code: 503
# 150503040202 failed with code: 503
# 120602010701 failed with code: 503
# 080602020606 failed with code: 503
# 120601050203 failed with code: 503
# 120800030901 failed with code: 503
# 130600110701 failed with code: 503
# 031300030705 failed with code: 503
# 150502020704 failed with code: 503
# 080402060907 failed with code: 503
# 120301020502 failed with code: 503
# 080500020505 failed with code: 503
# 120800020605 failed with code: 503
# 030701040601 failed with code: 503
# 130500040307 failed with code: 503
# 120100010504 failed with code: 503
# 120100010606 failed with code: 503
# 080500030106 failed with code: 503
# 130302021205 failed with code: 503
# 120601050201 failed with code: 503
# 130700070302 failed with code: 503
# 031502011206 failed with code: 503
# 150502010503 failed with code: 503
# 150503040204 failed with code: 503
# 130500031902 failed with code: 503
# 130700070202 failed with code: 503
# 130302021401 failed with code: 503
# 030701060405 failed with code: 503
# 031502030401 failed with code: 503
# 130600111006 failed with code: 503
# 111403060411 failed with code: 503
# 080402060701 failed with code: 503
# 120800030905 failed with code: 503
# 031800011001 failed with code: 503
# 130500032204 failed with code: 503
# 120800030704 failed with code: 503
# 080402060902 failed with code: 503
# 111403070209 failed with code: 503
# 150400030701 failed with code: 503
# 120301070202 failed with code: 503
# 130302021008 failed with code: 503
# 120800020401 failed with code: 503
# 120301050204 failed with code: 503
# 150502020703 failed with code: 503
# 150503010404 failed with code: 503
# 031501100801 failed with code: 503
# 120301020307 failed with code: 503
# 080602020703 failed with code: 503
# 120601050304 failed with code: 503
# 130600111008 failed with code: 503
# 030701040701 failed with code: 503
# 130301020801 failed with code: 503
# 150502020707 failed with code: 503
# 120601020201 failed with code: 503
# 150502010502 failed with code: 503
# 031602020501 failed with code: 503
# 120100030304 failed with code: 503
# 031300070105 failed with code: 503
# 111402050307 failed with code: 503
# 120601020607 failed with code: 503
# 120100020205 failed with code: 503
# 150503020103 failed with code: 503
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\dwieferich\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             try:  # Python 2.7, use buffering of HTTP responses
# --> 379                 httplib_response = conn.getresponse(buffering=True)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-b732f05c430f> in <module>()
#      46         try:
#      47             d=[]
# ---> 48             r = requests.post(url,data=payload)
#      49             status = str(r.status_code)
#      50             if r.status_code == 200:
#
# C:\Users\dwieferich\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\api.py in post(url, data, json, **kwargs)
#     110     """
#     111
# --> 112     return request('post', url, data=data, json=json, **kwargs)
#     113
#     114
#
# C:\Users\dwieferich\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# C:\Users\dwieferich\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     516         }
#     517         send_kwargs.update(settings)
# --> 518         resp = self.send(prep, **send_kwargs)
#     519
#     520         return resp
#
# C:\Users\dwieferich\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     637
#     638         # Send the request
# --> 639         r = adapter.send(request, **kwargs)
#     640
#     641         # Total elapsed time of the request (approximately)
#
# C:\Users\dwieferich\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     436                     decode_content=False,
#     437                     retries=self.max_retries,
# --> 438                     timeout=timeout
#     439                 )
#     440
#
# C:\Users\dwieferich\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# C:\Users\dwieferich\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#     381                 try:
# --> 382                     httplib_response = conn.getresponse()
#     383                 except Exception as e:
#     384                     # Remove the TypeError from the exception chain in Python 3;
#
# C:\Users\dwieferich\AppData\Local\Continuum\Anaconda3\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# C:\Users\dwieferich\AppData\Local\Continuum\Anaconda3\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# C:\Users\dwieferich\AppData\Local\Continuum\Anaconda3\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# C:\Users\dwieferich\AppData\Local\Continuum\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# C:\Users\dwieferich\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     275     def recv_into(self, *args, **kwargs):
#     276         try:
# --> 277             return self.connection.recv_into(*args, **kwargs)
#     278         except OpenSSL.SSL.SysCallError as e:
#     279             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# C:\Users\dwieferich\AppData\Local\Continuum\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1544             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1545         else:
# -> 1546             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1547         self._raise_ssl_error(self._ssl, result)
#    1548
#
# KeyboardInterrupt:

# %% [markdown]
# # Error that keeps coming up:
# ConnectionError: HTTPSConnectionPool(host='gc2.datadistillery.org', port=443): Max retries exceeded with url: /api/v1/sql/bcb (Caused by NewConnectionError('
#  <requests.packages.urllib3.connection.VerifiedHTTPSConnection object at  0x00000234DBEEC588>:
#  Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))

# %%
#The below numbers should be the same when initially processing the file.  This could be built into an automated test later on.
print ('Length of existing features list: ' + lenList)
print ('Existing features that were not processed: ' + cntExisting)

# %%
df = pd.DataFrame(d)
for index, row in df.iterrows():
    if  row['status'] != '200':
        print row['comid'], '           ', row['coordCnt'], '                       ', row['status']

# %%
print (url)
# Out:
# https://gc2.datadistillery.org/api/v1/sql/bcb

# %%
#Testing for keeping zip gdb in memory.  
#Code Failed when trying to view specific layer.

import requests
import uuid
import geopandas as gpd
from osgeo import gdal
import fiona

#requests = requests.get()
vsiz = '/vsimem/{}.zip'.format(uuid.uuid4().hex)
gdal.FileFromMemBuffer(vsiz,bytes(mysock))
with fiona.Collection(vsiz, vsi='zip', layer='Hucs') as f:
    gdf =gpd.GeoDataFrame.from_features(f,crs=f.crs)
# Out:
# ---------------------------------------------------------------------------
# FionaValueError                           Traceback (most recent call last)
# <ipython-input-23-eea40def378d> in <module>()
#       8 vsiz = '/vsimem/{}.zip'.format(uuid.uuid4().hex)
#       9 gdal.FileFromMemBuffer(vsiz,bytes(mysock))
# ---> 10 with fiona.Collection(vsiz, vsi='zip', layer='Hucs') as f:
#      11     gdf =gpd.GeoDataFrame.from_features(f,crs=f.crs)
#
# C:\Users\dwieferich\AppData\Local\Continuum\Anaconda3\lib\site-packages\fiona\collection.py in __init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, **kwargs)
#     151             if self.mode == 'r':
#     152                 self.session = Session()
# --> 153                 self.session.start(self)
#     154             elif self.mode in ('a', 'w'):
#     155                 self.session = WritingSession()
#
# fiona/ogrext.pyx in fiona.ogrext.Session.start (fiona/ogrext2.c:8570)()
#
# FionaValueError: No dataset found at path '/vsizip//vsimem/f943e5efbec74f2caa8b60b2c54b11d9.zip' using drivers: *
